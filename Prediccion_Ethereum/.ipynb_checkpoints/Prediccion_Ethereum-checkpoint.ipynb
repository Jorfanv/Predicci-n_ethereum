# %%
# Segmentar la información en conjuntos de 100 datos 
# hayar la distribución de cada conjunto 
# Hacer el poceso con cada distribución

# %%
# Instalar modulos necesarios
#!pip install yfinance==0.1.63
# Out:
# Collecting yfinance==0.1.63
#   Downloading yfinance-0.1.63.tar.gz (26 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.24 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from yfinance==0.1.63) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from yfinance==0.1.63) (1.21.6)
# Requirement already satisfied: requests>=2.20 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from yfinance==0.1.63) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from yfinance==0.1.63) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from yfinance==0.1.63) (4.9.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from pandas>=0.24->yfinance==0.1.63) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from pandas>=0.24->yfinance==0.1.63) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from requests>=2.20->yfinance==0.1.63) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from requests>=2.20->yfinance==0.1.63) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from requests>=2.20->yfinance==0.1.63) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from requests>=2.20->yfinance==0.1.63) (2.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\jorfa\anaconda3\envs\stan_env\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance==0.1.63) (1.16.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23959 sha256=acb567421537ff416660bdd8d12b77cf6e5dbd5cb915adacfc761e4fc01a8fde
#   Stored in directory: c:\users\jorfa\appdata\local\pip\cache\wheels\14\5e\8b\1c95139f27f44010bba7c779d572949b1b4bf4b1ef79cb725a
# Successfully built yfinance
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.31
#     Uninstalling yfinance-0.2.31:
#       Successfully uninstalled yfinance-0.2.31
# Successfully installed yfinance-0.1.63

# %%
# Importar librerias 
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pystan

# %%
eth_symbol = "ETH-USD"

start_date = "2023-08-01"
end_date = "2023-10-05"

eth_data = yf.download(eth_symbol, start=start_date, end=end_date, interval="1h")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#eth_data = eth_data.head(5)

# %%
#eth_data.to_csv('eth_data.csv')

# %%
eth_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
eth_data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1560.000000  1560.000000  1560.000000  1560.000000  1560.000000
# mean   1689.993080  1693.052965  1686.860711  1689.880609  1689.880609
# std      91.848748    91.502386    92.183591    91.784077    91.784077
# min    1538.777588  1545.406250  1533.426758  1539.252930  1539.252930
# 25%    1629.933289  1632.357086  1627.104919  1629.926636  1629.926636
# 50%    1650.570496  1653.825500  1648.034119  1650.520325  1650.520325
# 75%    1788.628235  1790.413513  1783.222168  1787.096558  1787.096558
# max    1873.468140  1877.511475  1867.970581  1873.029907  1873.029907
#
#              Volume
# count  1.560000e+03
# mean   6.178017e+07
# std    1.716701e+08
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    5.430618e+07
# max    2.530970e+09

# %%
eth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1560 entries, 2023-08-01 05:00:00+00:00 to 2023-10-05 04:00:00+00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1560 non-null   float64
#  1   High       1560 non-null   float64
#  2   Low        1560 non-null   float64
#  3   Close      1560 non-null   float64
#  4   Adj Close  1560 non-null   float64
#  5   Volume     1560 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 85.3 KB

# %% [markdown]
# ## Presentación de las gráficas

# %%
# Gráfico precios de cierre ETH 
plt.figure(figsize=(15, 9))
plt.plot(eth_data.index, eth_data['Close'], linestyle='-', color = 'black')
plt.scatter(eth_data.index, eth_data['High'], color='green', marker='o', label='Puntos de datos', s = 0.5)
plt.scatter(eth_data.index, eth_data['Low'], color='red', marker='o', label='Puntos de datos', s = 0.5)
plt.title(f"Precios de cierre entre {eth_data.index[0].strftime('%d/%m/%Y %H:%M:%S')} y {eth_data.index[-1].strftime('%d/%m/%Y %H:%M:%S')}")
plt.xlabel("Date")
plt.ylabel("Close")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Gráfico precios de cierre ETH 
plt.figure(figsize=(30, 20))
#plt.plot(eth_data.index, eth_data['Close'], linestyle='-', color = 'black')
plt.plot(eth_data.index, eth_data['High'], color='green', linestyle='-')
plt.plot(eth_data.index, eth_data['Low'], color='red', linestyle='-')
plt.title(f"Precios de cierre entre {eth_data.index[0].strftime('%d/%m/%Y %H:%M:%S')} y {eth_data.index[-1].strftime('%d/%m/%Y %H:%M:%S')}")
plt.xlabel("Date")
plt.ylabel("Close")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Gráfico Volume ETH 
plt.figure(figsize=(15, 9))
plt.plot(eth_data.index, eth_data['Volume'], linestyle='-', color = 'black')
plt.title(f"Volume entre {eth_data.index[0].strftime('%d/%m/%Y %H:%M:%S')} y {eth_data.index[-1].strftime('%d/%m/%Y %H:%M:%S')}")
plt.xlabel("Volume")
plt.ylabel("Date")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Histograma de precios de cierre ETH
plt.figure(figsize=(15, 9))
plt.hist(eth_data['Close'], bins=20, color='blue', edgecolor='black')
plt.title("Histograma de Precios de cierre")
plt.xlabel("Precio de cierre")
plt.ylabel("Frecuencia")
plt.grid(True)
plt.show()

# %%
#@title Calculo variables adicionales
eth_data['SMA_24'] = eth_data['Close'].rolling(window=20).mean()
# indicador de volatilidad (desviación estándar de 20 días)
eth_data['Volatility_24'] = eth_data['Close'].rolling(window=20).std()

# %%
eth_data.iloc[:, -2:]
# Out:
#                                 SMA_24  Volatility_24
# 2023-08-01 05:00:00+00:00          NaN            NaN
# 2023-08-01 06:00:00+00:00          NaN            NaN
# 2023-08-01 07:00:00+00:00          NaN            NaN
# 2023-08-01 08:00:00+00:00          NaN            NaN
# 2023-08-01 09:00:00+00:00          NaN            NaN
# ...                                ...            ...
# 2023-10-05 00:00:00+00:00  1643.133691       5.340981
# 2023-10-05 01:00:00+00:00  1643.482697       5.368766
# 2023-10-05 02:00:00+00:00  1643.618890       5.355127
# 2023-10-05 03:00:00+00:00  1643.532336       5.349175
# 2023-10-05 04:00:00+00:00  1643.438531       5.308202
#
# [1560 rows x 2 columns]

# %%
# Media móvil
plt.figure(figsize=(15, 9))
plt.plot(eth_data.index, eth_data['SMA_24'], linestyle='-', color = 'black')
plt.title(f"Media móvil de precios de cierre entre {eth_data.index[0].strftime('%d/%m/%Y %H:%M:%S')} y {eth_data.index[-1].strftime('%d/%m/%Y %H:%M:%S')}")
plt.xlabel("Date")
plt.ylabel("Close")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Volatilidad móvil 
plt.figure(figsize=(15, 9))
plt.plot(eth_data.index, eth_data['Volatility_24'], linestyle='-', color = 'black')
plt.title(f"Volatilidad de los precios de cierre entre {eth_data.index[0].strftime('%d/%m/%Y %H:%M:%S')} y {eth_data.index[-1].strftime('%d/%m/%Y %H:%M:%S')}")
plt.xlabel("Date")
plt.ylabel("Porcentaje")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Modelo Ornstein-Uhlenbeck

# %% [markdown]
# ## Modelado priors

# %%
data {
  int<lower=0> n;  // Número de lanzamientos
  int<lower=0> y;  // Número de caras
}

parameters {
  real<lower=0, upper=1> p_uniforme;  // Probabilidad de cara usando prior uniforme
  real<lower=0, upper=1> p_beta;      // Probabilidad de cara usando prior beta
  real<lower=0, upper=1> p_normal;    // Probabilidad de cara usando prior normal
}

model {
  // Priors
  p_uniforme ~ uniform(0, 1);  // Distribución uniforme entre 0 y 1
  p_beta ~ beta(2, 2);         // Distribución beta con parámetros alpha=2 y beta=2
  p_normal ~ normal(0.5, 0.1); // Distribución normal con media 0.5 y desviación estándar 0.1

  // Likelihood
  y ~ binomial(n, p_uniforme);
  y ~ binomial(n, p_beta);
  y ~ binomial(n, p_normal);
}
# Out:
#   Cell In[1], line 1
#     data {
#          ^
# SyntaxError: invalid syntax

# %%
import pystan

# Definición del código Stan
stan_code = """
... (aquí va el código Stan de arriba) ...
"""

# Compilación del modelo
sm = pystan.StanModel(model_code=stan_code)

# Datos para el ajuste
data = {
    'n': 100,  # 100 lanzamientos
    'y': 61   # 61 caras
}

# Ajuste del modelo a los datos
fit = sm.sampling(data=data, iter=1000, chains=4)

# Resumen del ajuste
print(fit)
